# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re

np.random.seed(28)

# %%
df = pd.read_csv("resources/all_data_info.csv")

# %%
df
# Out:
#                          artist    date               genre  pixelsx  pixelsy  \
# 0                Barnett Newman  1955.0            abstract  15530.0   6911.0
# 1                Barnett Newman  1950.0            abstract  14559.0   6866.0
# 2                   kiri nichol  2013.0                 NaN   9003.0   9004.0
# 3                   kiri nichol  2013.0                 NaN   9003.0   9004.0
# 4                   kiri nichol  2013.0                 NaN   9003.0   9004.0
# ...                         ...     ...                 ...      ...      ...
# 103245          Jackson Pollock  1948.0            abstract    682.0    220.0
# 103246         Bernardo Strozzi     NaN  religious painting    329.0    456.0
# 103247               Josef Sima     NaN           landscape    293.0    512.0
# 103248           Brett Whiteley  1982.0              marina    293.0    512.0
# 103249  Amadeo de Souza-Cardoso    1913           landscape    293.0    512.0
#
#         size_bytes   source                 style                     title  \
# 0        9201912.0  wikiart  Color Field Painting                     Uriel
# 1        8867532.0  wikiart  Color Field Painting     Vir Heroicus Sublimis
# 2        1756681.0      NaN         Neoplasticism                       NaN
# 3        1942046.0      NaN         Neoplasticism                       NaN
# 4        1526212.0      NaN         Neoplasticism                       NaN
# ...            ...      ...                   ...                       ...
# 103245     96405.0  wikiart       Action painting    Number 13A (Arabesque)
# 103246    127594.0  wikiart               Baroque     St. Francis of Assisi
# 103247    102519.0  wikiart            Surrealism  Maisons à la campagne II
# 103248    167423.0  wikiart                   NaN           Thebe's Revenge
# 103249     77577.0  wikiart                Cubism            House Manhufe
#
#           artist_group  in_train new_filename
# 0           train_only      True   102257.jpg
# 1           train_only      True    75232.jpg
# 2            test_only     False    32145.jpg
# 3            test_only     False    20304.jpg
# 4            test_only     False      836.jpg
# ...                ...       ...          ...
# 103245  train_and_test      True    25525.jpg
# 103246      train_only      True    47038.jpg
# 103247  train_and_test     False     7680.jpg
# 103248  train_and_test      True     9021.jpg
# 103249      train_only      True    36564.jpg
#
# [103250 rows x 12 columns]

# %%
art = df[["artist", "date", "style", "genre", "title", "new_filename", "artist_group"]]

# %%
non_duplicates = art.drop_duplicates()

# %%
def clean_year(item):
    string = str(item)
    try:
        year = re.findall(r"\d{3,4}", string)[0]
    except Exception as e:
        print(item, string)
        return ''
    return int(year)

# %%
# non_duplicates.dropna(subset=["date"], inplace=True)
# non_duplicates["new_date"] = non_duplicates["date"].apply(clean_year)
# non_duplicates = non_duplicates[non_duplicates["new_date"] != ''].copy()

# %%
non_duplicates
# Out:
#                          artist    date                 style  \
# 0                Barnett Newman  1955.0  Color Field Painting
# 1                Barnett Newman  1950.0  Color Field Painting
# 2                   kiri nichol  2013.0         Neoplasticism
# 3                   kiri nichol  2013.0         Neoplasticism
# 4                   kiri nichol  2013.0         Neoplasticism
# ...                         ...     ...                   ...
# 103245          Jackson Pollock  1948.0       Action painting
# 103246         Bernardo Strozzi     NaN               Baroque
# 103247               Josef Sima     NaN            Surrealism
# 103248           Brett Whiteley  1982.0                   NaN
# 103249  Amadeo de Souza-Cardoso    1913                Cubism
#
#                      genre                     title new_filename  \
# 0                 abstract                     Uriel   102257.jpg
# 1                 abstract     Vir Heroicus Sublimis    75232.jpg
# 2                      NaN                       NaN    32145.jpg
# 3                      NaN                       NaN    20304.jpg
# 4                      NaN                       NaN      836.jpg
# ...                    ...                       ...          ...
# 103245            abstract    Number 13A (Arabesque)    25525.jpg
# 103246  religious painting     St. Francis of Assisi    47038.jpg
# 103247           landscape  Maisons à la campagne II     7680.jpg
# 103248              marina           Thebe's Revenge     9021.jpg
# 103249           landscape            House Manhufe     36564.jpg
#
#           artist_group
# 0           train_only
# 1           train_only
# 2            test_only
# 3            test_only
# 4            test_only
# ...                ...
# 103245  train_and_test
# 103246      train_only
# 103247  train_and_test
# 103248  train_and_test
# 103249      train_only
#
# [103250 rows x 7 columns]

# %%
ranking = non_duplicates[["new_filename", "style"]].groupby(["style"]).nunique().sort_values(["new_filename"],ascending=False)

# %%
ranking[:15]
# Out:
#                          new_filename  style
# style
# Impressionism                   10643      1
# Realism                         10523      1
# Romanticism                      9285      1
# Expressionism                    7013      1
# Post-Impressionism               5778      1
# Art Nouveau (Modern)             4899      1
# Baroque                          4400      1
# Surrealism                       4167      1
# Symbolism                        3476      1
# Rococo                           2733      1
# Northern Renaissance             2379      1
# Naïve Art (Primitivism)          2295      1
# Abstract Expressionism           2074      1
# Neoclassicism                    2038      1
# Cubism                           1747      1

# %%
top_15 = list(ranking[:15].index)

# %% [markdown]
# -- 22,500 images
# -- top 15 styles
# -- 22,500 / 15 = 1500 images per category
# -- 1050, 450 train/test split

# %%
top_15
# Out:
# ['Impressionism',
#  'Realism',
#  'Romanticism',
#  'Expressionism',
#  'Post-Impressionism',
#  'Art Nouveau (Modern)',
#  'Baroque',
#  'Surrealism',
#  'Symbolism',
#  'Rococo',
#  'Northern Renaissance',
#  'Naïve Art (Primitivism)',
#  'Abstract Expressionism',
#  'Neoclassicism',
#  'Cubism']

# %%
top_15
# Out:
# ['Impressionism',
#  'Realism',
#  'Romanticism',
#  'Expressionism',
#  'Post-Impressionism',
#  'Art Nouveau (Modern)',
#  'Baroque',
#  'Surrealism',
#  'Symbolism',
#  'Rococo',
#  'Northern Renaissance',
#  'Naïve Art (Primitivism)',
#  'Abstract Expressionism',
#  'Neoclassicism',
#  'Cubism']

# %%
N_SAMPLES_PER = 1600
TEST_PCT = .30

# %%
def split_genre(style):
    np.random.seed(28)
    style_list = non_duplicates[non_duplicates['style'] == style]['new_filename']
    style_files = np.random.choice(style_list, (N_SAMPLES_PER), replace=False)
    y = np.ones(N_SAMPLES_PER)
    X_train, X_test, y_train, y_test = train_test_split(style_files, y, test_size=TEST_PCT, random_state=42)
    return X_train, X_test

# %%
def sample_genre(style):
    np.random.seed(28)
    X_train, X_test = split_genre(style)
    train = non_duplicates[non_duplicates["new_filename"].isin(X_train)].copy()
    test = non_duplicates[non_duplicates["new_filename"].isin(X_test)].copy()
    
    train["group"] = "train"
    test["group"] = "test"
    
    return pd.concat([train, test])

# %%
sample_genre("Impressionism")
# Out:
#                          artist    date          style              genre  \
# 402                 Paul Signac    1922  Impressionism          cityscape
# 504                 Paul Signac  c.1921  Impressionism          landscape
# 1083              Alfred Sisley    1871  Impressionism          landscape
# 1087               Claude Monet    1886  Impressionism          landscape
# 1336                Anders Zorn    1893  Impressionism     genre painting
# ...                         ...     ...            ...                ...
# 100930   James McNeill Whistler    1895  Impressionism           portrait
# 101304              Firmin Baes     NaN  Impressionism     genre painting
# 101650  Nikolay Bogdanov-Belsky     NaN  Impressionism     genre painting
# 101873              Max Slevogt  1917.0  Impressionism  wildlife painting
# 102437  Nikolay Bogdanov-Belsky     NaN  Impressionism     genre painting
#
#                              title new_filename    artist_group  group
# 402      Le Havre with rain clouds     8250.jpg  train_and_test  train
# 504            Saint Paul de Vence    95477.jpg  train_and_test  train
# 1083    River steamboat and bridge    34200.jpg  train_and_test  train
# 1087           Haystack at Giverny    52023.jpg  train_and_test  train
# 1336                       Omnibus   100236.jpg  train_and_test  train
# ...                            ...          ...             ...    ...
# 100930      Edward Guthrie Kennedy    87589.jpg  train_and_test   test
# 101304               Sunny terrace    69399.jpg      train_only   test
# 101650                   Fisherman    30921.jpg  train_and_test   test
# 101873        Tiger in the Jungle     15421.jpg  train_and_test   test
# 102437                 On the Lake    88446.jpg  train_and_test   test
#
# [1600 rows x 8 columns]

# %%
def get_sample():
    dfs = [sample_genre(style) for style in top_15]
    return pd.concat(dfs)

# %%
sample = get_sample()
sample
# Out:
#                            artist    date          style             genre  \
# 402                   Paul Signac    1922  Impressionism         cityscape
# 504                   Paul Signac  c.1921  Impressionism         landscape
# 1083                Alfred Sisley    1871  Impressionism         landscape
# 1087                 Claude Monet    1886  Impressionism         landscape
# 1336                  Anders Zorn    1893  Impressionism    genre painting
# ...                           ...     ...            ...               ...
# 102198                  Juan Gris    1920         Cubism  sketch and study
# 102240           Willi Baumeister  1930.0         Cubism          abstract
# 102346              Henri Laurens  1915.0         Cubism          portrait
# 102890           Roy Lichtenstein  1980.0         Cubism         landscape
# 103128  Marevna (Marie Vorobieff)     NaN         Cubism        still life
#
#                                      title new_filename    artist_group  group
# 402              Le Havre with rain clouds     8250.jpg  train_and_test  train
# 504                    Saint Paul de Vence    95477.jpg  train_and_test  train
# 1083            River steamboat and bridge    34200.jpg  train_and_test  train
# 1087                   Haystack at Giverny    52023.jpg  train_and_test  train
# 1336                               Omnibus   100236.jpg  train_and_test  train
# ...                                    ...          ...             ...    ...
# 102198                           Harlequin    87717.jpg  train_and_test   test
# 102240        Machine Man with Spiral Turn    40473.jpg  train_and_test   test
# 102346                    Head of a Woman     32438.jpg      train_only   test
# 102890  Landscape with figures and rainbow     2862.jpg      train_only   test
# 103128                   Cubist Sunflowers    95093.jpg      train_only   test
#
# [24000 rows x 8 columns]

# %%
filename = ''

# %%
# sample.to_csv(f"utils/{filename}.csv")

# %%
f = open(filename, 'rb')
data = pickle.load(f)
f.close()
